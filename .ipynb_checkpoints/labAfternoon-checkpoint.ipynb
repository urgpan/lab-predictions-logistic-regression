# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
engine = create_engine(connection_string)

# %%
query = '''with cte_rental as (
select
i.film_id,
date_format(convert(r.rental_date,date), '%m') as r_month,
date_format(convert(r.rental_date,date), '%Y') as r_year
from sakila.rental as r
right join sakila.inventory as i
on r.inventory_id=i.inventory_id
)
select f.film_id,cte.r_month, cte.r_year, f.rental_duration, f.rental_rate, f.length, f.rating, f.special_features, c.category_id,
case
when f.film_id in (select film_id from rental as r
join inventory as i
using(inventory_id)
join film as f
using(film_id)
where date_format(convert(r.rental_date,date), '%m') =2) then 1
else 0
end as rented_last_month
from cte_rental as cte
join sakila.film as f
on cte.film_id=f.film_id
join sakila.film_category as c
on f.film_id=c.film_id
;
'''

data = pd.read_sql_query(query, engine)

# %%
data.shape
# Out:
# (16046, 10)

# %% [markdown]
# # DROP UNWANTED COLUMNS

# %%
def dropping_columns(df,columns):
    df = df.drop(columns, axis = 1)
    return df

# %%
#data = dropping_columns(data,['language_id'])

# %% [markdown]
# # SPECIAL FEATURES

# %%
def count_special_features(data_list):
    lx = lambda x: x.split(sep=',') #split by comas
    ly = lambda x: len(x) #lenght of the array
    #apply funtions
    data_list = data_list.apply(lx)
    data_list = data_list.apply(ly)
    return data_list

# %%
data['special_features'] = count_special_features(data['special_features'])

# %% [markdown]
# # DUMMY RATING

# %%
def rating_ordi(x)  :
    if x== "G":
        x= 1
    elif x== "PG":
        x=2
    elif x== "PG-13":
        x=3
    elif x== "R":
        x=4
    else:
        x=5
    return x

# %%
data["rating"]=list(map(rating_ordi,data["rating"]))

# %% [markdown]
# # DROP NA

# %%
data = data[data['r_month'].isna() == False]
data = data[data['r_year'].isna() == False]

# %% [markdown]
# # CONVERTING INTO NUMBER

# %%
z = lambda x: int(x)
data['r_month'] = list(map(z,data['r_month']))
data['r_year'] = list(map(z,data['r_year']))

# %%
data.dtypes
# Out:
# film_id                int64
# r_month                int64
# r_year                 int64
# rental_duration        int64
# rental_rate          float64
# length                 int64
# rating                 int64
# special_features       int64
# category_id            int64
# rented_last_month      int64
# dtype: object

# %%
data.isna().sum()
# Out:
# film_id              0
# r_month              0
# r_year               0
# rental_duration      0
# rental_rate          0
# length               0
# rating               0
# special_features     0
# category_id          0
# rented_last_month    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
corr_matrix=data.corr(method='pearson')  # default
fig, ax = plt.subplots(figsize=(20, 16))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
def scaling(df,target,scaler):
    from sklearn.preprocessing import StandardScaler
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.preprocessing import Normalizer
    #x-y-split
    Y=df[target]
    X=df.drop([target],axis=1)
    #chosing scaler
    #StandardScaler
    if scaler=="StandardScaler":
        scaler_x = StandardScaler().fit(X)
        X_scaled = pd.DataFrame(scaler_x.transform(X),columns=X.columns)
        return X_scaled,Y
    #MinMaxScaler()
    elif scaler=="MinMax":
        X_scaled = MinMaxScaler().fit_transform(X.values)
        X_scaled = pd.DataFrame(X_scaled,columns=X.columns)
        return X_scaled,Y
    #Normalizer
    elif scaler=="Normalizer":
        transformer = Normalizer().fit(X)
        X_scaled = pd.DataFrame(transformer.transform(X),columns=X.columns)
        return X_scaled,Y

# %%
x_scaled, y = scaling(data,'rented_last_month','StandardScaler')

# %%
for col in list(x_scaled.columns):
    print(col)
    sns.displot(x_scaled[col])
    plt.show()
# Out:
# film_id
# r_month
# r_year
# rental_duration
# rental_rate
# length
# rating
# special_features
# category_id

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.4, random_state=100)

# %%
from sklearn.linear_model import LogisticRegression
classification = LogisticRegression(random_state=0, solver='lbfgs',
                  multi_class='multinomial').fit(X_train, y_train)#multiclass, categorical fuetures with mmore than two value

# %%
print("The accuracy of the model in the TEST set is: ", round(classification.score(X_test, y_test),2))
# Out:
# The accuracy of the model in the TEST set is:  0.81

# %%
predictions = classification.predict(X_test)
classification.score(X_test, y_test)
# Out:
# 0.8141165472109692

# %%
y_test.value_counts() #huge imbalance
# Out:
# 0    5161
# 1    1257
# Name: rented_last_month, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[5161,    0],
#        [1193,   64]], dtype=int64)

# %%
plot_confusion_matrix(classification, X_test, y_test)
